# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    297     38   John  January      Q1
# 1  2023-01-02       B   West    513     28   Mary  January      Q1
# 2  2023-01-03       C  North    454     12    Bob  January      Q1
# 3  2023-01-04       D  South    277     22  Alice  January      Q1
# 4  2023-01-05       A   East    268     47   John  January      Q1
# 5  2023-01-06       B   West    384     36   Mary  January      Q1
# 6  2023-01-07       C  North    309     44    Bob  January      Q1
# 7  2023-01-08       D  South    413     32  Alice  January      Q1
# 8  2023-01-09       A   East    309     90   John  January      Q1
# 9  2023-01-10       B   West    143     49   Mary  January      Q1
# 10 2023-01-11       C  North    254     47    Bob  January      Q1
# 11 2023-01-12       D  South    908     95  Alice  January      Q1
# 12 2023-01-13       A   East    258     18   John  January      Q1
# 13 2023-01-14       B   West    469     60   Mary  January      Q1
# 14 2023-01-15       C  North    162     91    Bob  January      Q1
# 15 2023-01-16       D  South    300     69  Alice  January      Q1
# 16 2023-01-17       A   East    196     27   John  January      Q1
# 17 2023-01-18       B   West    347     97   Mary  January      Q1
# 18 2023-01-19       C  North    852     89    Bob  January      Q1
# 19 2023-01-20       D  South    989     67  Alice  January      Q1

# %%
#It is aminly used to  create heat map 
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     268.0    NaN    NaN    NaN
# North      NaN    NaN  309.0    NaN
# South      NaN    NaN    NaN  413.0
# West       NaN  384.0    NaN    NaN

# %%
#When  you are creating a values it must be numarical 
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     265.6    NaN    NaN    NaN  44.0   NaN   NaN   NaN
# North      NaN    NaN  406.2    NaN   NaN   NaN  56.6   NaN
# South      NaN    NaN    NaN  577.4   NaN   NaN   NaN  57.0
# West       NaN  371.2    NaN    NaN   NaN  54.0   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
#It is same like pivot function but in pivot we use aggregative fumction here we use counting functions
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
